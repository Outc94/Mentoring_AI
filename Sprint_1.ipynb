# %% [markdown]
# # Sprint 1

# %% [markdown]
# ## Problem 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('application_train.csv')

# %%
df2 = df
list_str=[]
for i in df.columns:
    if df[i].dtypes == 'O':
        df2 = df2.drop([i], axis = 1)
        list_str.append(i)
df2 = df2.replace(np.nan,0)
df_str = df[list_str]
df_dummy = pd.get_dummies(df_str)
df_mix = pd.concat([df2, df_dummy], axis=1)

# %%
df_dummy.head(10)
# Out:
#    NAME_CONTRACT_TYPE_Cash loans  NAME_CONTRACT_TYPE_Revolving loans  \
# 0                              1                                   0
# 1                              1                                   0
# 2                              0                                   1
# 3                              1                                   0
# 4                              1                                   0
# 5                              1                                   0
# 6                              1                                   0
# 7                              1                                   0
# 8                              1                                   0
# 9                              0                                   1
#
#    CODE_GENDER_F  CODE_GENDER_M  CODE_GENDER_XNA  FLAG_OWN_CAR_N  \
# 0              0              1                0               1
# 1              1              0                0               1
# ...

# %%
df_mix.head(10)
# Out:
#    SK_ID_CURR  TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 0      100002       1             0          202500.0    406597.5
# 1      100003       0             0          270000.0   1293502.5
# 2      100004       0             0           67500.0    135000.0
# 3      100006       0             0          135000.0    312682.5
# 4      100007       0             0          121500.0    513000.0
# 5      100008       0             0           99000.0    490495.5
# 6      100009       0             1          171000.0   1560726.0
# 7      100010       0             0          360000.0   1530000.0
# 8      100011       0             0          112500.0   1019610.0
# 9      100012       0             0          135000.0    405000.0
#
#    AMT_ANNUITY  AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  DAYS_BIRTH  \
# 0      24700.5         351000.0                    0.018801       -9461
# 1      35698.5        1129500.0                    0.003541      -16765
# ...

# %%
from scipy.stats import pearsonr
list_i = []
for i in df_mix.columns:
    a, b = pearsonr(df_mix[i],df_mix["TARGET"])
    if 0.06 < abs(a) :
        list_i.append(i)
        
list_i = list_i[1:]
X = df_mix[list_i]
y = df_mix["TARGET"]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_std = sc.fit_transform(X)

# %% [markdown]
# Now we will use the KFold class to devide it multiple times

# %%
from sklearn.model_selection import KFold
kfold = KFold(n_splits=10)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

reg = KNeighborsClassifier(n_neighbors=3)
cross_val_score(reg, X, y, cv=kfold)
# Out:
# array([0.90296566, 0.90393808, 0.90198693, 0.90107639, 0.9015967 ,
#        0.90335274, 0.90309258, 0.90540145, 0.90384053, 0.90432831])

# %%
cross_val_score(reg, X, y, cv=kfold).mean()
# Out:
# 0.9031579364389424

# %%
(X_train, X_test,
 y_train, y_test) = train_test_split(
    X, y, test_size=0.25, random_state=0,
)
reg = KNeighborsClassifier(n_neighbors=3)
reg.fit(X_train, y_train)
reg_pred = reg.predict(X_test)

# %% [markdown]
# ## Problem 2

# %% [markdown]
# Let's now use GridSerachCV

# %%
list_i = []
for i in df_mix.columns:
    a, b = pearsonr(df_mix[i],df_mix["TARGET"])
    if 0.05 < abs(a) :
        list_i.append(i)

list_i = list_i[1:]
X = df_mix[list_i]
y = df_mix["TARGET"]

# %%
sc = StandardScaler()
X_std = sc.fit_transform(X)

# %%
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

# %%
reg = LogisticRegression()
parameters = {'penalty': ['l1', 'l2'],'C': [100, 50, 10, 1, 0.5, 0.1, 0.01]}
gri_sear = GridSearchCV(estimator=reg, param_grid=parameters, cv=5, scoring="roc_auc")
gri_sear.fit(X_std, y)
# Out:
# /Users/diopmouhamed/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/diopmouhamed/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/diopmouhamed/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/diopmouhamed/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
gri_sear.best_score_
# Out:
# 0.7124487621900487

# %%
import lightgbm as lgb
reg =  lgb.LGBMRegressor()
parameters = {'n_estimators': [10, 100 , 150], 'max_depth': [3, 5, 7, 10]}
gri_sear = GridSearchCV(estimator=reg, param_grid=parameters, cv=5, scoring="roc_auc")
gri_sear.fit(X, y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=LGBMRegressor(boosting_type='gbdt', class_weight=None,
#                                      colsample_bytree=1.0,
#                                      importance_type='split', learning_rate=0.1,
#                                      max_depth=-1, min_child_samples=20,
#                                      min_child_weight=0.001, min_split_gain=0.0,
#                                      n_estimators=100, n_jobs=-1, num_leaves=31,
#                                      objective=None, random_state=None,
#                                      reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                                      subsample=1.0, subsample_for_bin=200000,
#                                      subsample_freq=0),
#              iid='warn', n_jobs=None,
#              param_grid={'max_depth': [3, 5, 7, 10],
#                          'n_estimators': [10, 100, 150]},
# ...

# %%
gri_sear.best_score_
# Out:
# 0.7393519023985035

# %% [markdown]
# ## Problem 3

# %% [markdown]
# Various ideas can be identified in Kaggle's Notebooks:
#
# - Visualize the correlation coefficient in a graph
# - Focus on highly correlated features
# - Convert unimportant values to nan or 0 just like we have done previously
# - Use the average in analyzing
# - Standardization
# - Excluding and replacing (Outliers) and so on.

# %% [markdown]
# ## Problem 4

# %%
df2 = df
list_str=[]
for i in df.columns:
    if df[i].dtypes == 'O':
        df2 = df2.drop([i], axis = 1)
        list_str.append(i)
df2 = df2.replace(np.nan,0)
df_str = df[list_str]
df_dummy = pd.get_dummies(df_str)
df_mix = pd.concat([df2, df_dummy], axis=1)

# %%
df_mix["NA_count"] = pd.DataFrame(df.isnull().sum(axis=1))
df_mix.head()
# Out:
#    SK_ID_CURR  TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 0      100002       1             0          202500.0    406597.5
# 1      100003       0             0          270000.0   1293502.5
# 2      100004       0             0           67500.0    135000.0
# 3      100006       0             0          135000.0    312682.5
# 4      100007       0             0          121500.0    513000.0
#
#    AMT_ANNUITY  AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  DAYS_BIRTH  \
# 0      24700.5         351000.0                    0.018801       -9461
# 1      35698.5        1129500.0                    0.003541      -16765
# 2       6750.0         135000.0                    0.010032      -19046
# 3      29686.5         297000.0                    0.008019      -19005
# 4      21865.5         513000.0                    0.028663      -19932
#
#    DAYS_EMPLOYED  ...  WALLSMATERIAL_MODE_Block  WALLSMATERIAL_MODE_Mixed  \
# ...

# %%
list_i = []
for i in df_mix.columns:
    a, b = pearsonr(df_mix[i],df_mix["TARGET"])
    if 0.04 < abs(a) :
        list_i.append(i)
        
X = df_mix[list_i].drop("TARGET", axis=1)
y = df_mix["TARGET"]

(X_train, X_test,
 y_train, y_test) = train_test_split(
    X, y, test_size=0.25, random_state=0,
)

# %% [markdown]
# Let's see the number of outliers, if the number is 1 then we have a normal situation.

# %%
from sklearn.neighbors import LocalOutlierFactor
clf = LocalOutlierFactor(n_neighbors=10)
y_pred = clf.fit_predict(X_train)
ANOMALY_DATA = -1
predicted_outlier_index = np.where(y_pred == ANOMALY_DATA)
print("Number of outliers: {}".format(len(predicted_outlier_index)))
X_train = X_train.iloc[predicted_outlier_index]
y_train = y_train.iloc[predicted_outlier_index]
# Out:
# /Users/diopmouhamed/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/sklearn/neighbors/lof.py:236: FutureWarning: default contamination parameter 0.1 will change in version 0.22 to "auto". This will change the predict method behavior.
#   FutureWarning)
# Number of outliers: 1

# %%
sc = StandardScaler()
X_train_std = sc.fit_transform(X_train)
X_test_std = sc.transform(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.model_selection import GridSearchCV

# %%
clf = lgb.LGBMClassifier().fit(X_train, y_train)
y_pred =clf.predict(X_test)
print(clf)
print("{}".format(clf.score(X_test, y_test)))
print("{}".format(precision_score(y_test,y_pred)))
print("{}".format(recall_score(y_test,y_pred)))
print("{}".format(f1_score(y_test,y_pred)))
print(confusion_matrix(y_test,y_pred))
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# 0.9199901142069252
# 0.41329479768786126
# 0.023477261533409947
# 0.04443063538915643
# [[70584   203]
#  [ 5948   143]]

# %%
top_features = clf.feature_importances_.reshape(len(clf.feature_importances_),1)
column = np.array(X.columns).reshape(len(clf.feature_importances_),1)
feature = pd.DataFrame(np.hstack([column,top_features]), columns=["Columns", "Top Features"])
feature_sorted = feature.sort_values('Top Features', ascending=False).reset_index()
feature_sorted = feature_sorted.drop("index", axis=1)
feature_sorted.head()
# Out:
#                   Columns Top Features
# 0            EXT_SOURCE_2          342
# 1              DAYS_BIRTH          323
# 2  DAYS_LAST_PHONE_CHANGE          303
# 3            EXT_SOURCE_3          290
# 4         DAYS_ID_PUBLISH          280

# %%
feature_sorted["Top Features"] = feature_sorted["Top Features"].astype('float64')
list_col = []
for i in range(len(feature_sorted)):
    a = feature_sorted.iloc[i,0]
    b = feature_sorted.iloc[i,1]
    if b >= 30:
        list_col.append(a)

# %%
list_col
# Out:
# ['EXT_SOURCE_2',
#  'DAYS_BIRTH',
#  'DAYS_LAST_PHONE_CHANGE',
#  'EXT_SOURCE_3',
#  'DAYS_ID_PUBLISH',
#  'DAYS_REGISTRATION',
#  'DAYS_EMPLOYED',
#  'EXT_SOURCE_1',
#  'TOTALAREA_MODE',
#  'NA_count',
#  'LIVINGAREA_AVG',
#  'YEARS_BEGINEXPLUATATION_MODE',
#  'YEARS_BEGINEXPLUATATION_AVG',
#  'LIVINGAREA_MEDI',
#  'FLAG_DOCUMENT_3',
#  'FLOORSMAX_AVG',
#  'YEARS_BEGINEXPLUATATION_MEDI',
#  'NAME_INCOME_TYPE_Working']

# %%
X = X[list_col]
(X_train, X_test,
 y_train, y_test) = train_test_split(
    X, y, test_size=0.25, random_state=0,
)
sc = StandardScaler()
X_train_std = sc.fit_transform(X_train)
X_test_std = sc.transform(X_test)

# %%
clf = lgb.LGBMClassifier(max_depth=5, n_estimators=100).fit(X_train, y_train)
y_pred =clf.predict(X_test)
print(clf)
print("{}".format(clf.score(X_test, y_test)))
print("{}".format(precision_score(y_test,y_pred)))
print("{}".format(recall_score(y_test,y_pred)))
print("{}".format(f1_score(y_test,y_pred)))
print(confusion_matrix(y_test,y_pred))
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=5,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# 0.9206925258201306
# 0.46875
# 0.007387949433590543
# 0.01454663003070955
# [[70736    51]
#  [ 6046    45]]

# %%
clf = lgb.LGBMClassifier(max_depth=3, n_estimators=1000).fit(X_train, y_train)
y_pred =clf.predict(X_test)
print(clf)
print("{}".format(clf.score(X_test, y_test)))
print("{}".format(precision_score(y_test,y_pred)))
print("{}".format(recall_score(y_test,y_pred)))
print("{}".format(f1_score(y_test,y_pred)))
print(confusion_matrix(y_test,y_pred))
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=3,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=1000, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
# 0.92061448008533
# 0.46842105263157896
# 0.014611722213101298
# 0.028339436395478427
# [[70686   101]
#  [ 6002    89]]

# %%
from sklearn.metrics import roc_curve, roc_auc_score
reg = lgb.LGBMClassifier()
parameters = {'n_estimators': [10, 100 , 500, 1000], 'max_depth': [3, 5, 7, 10]}
gri_sear = GridSearchCV(estimator=reg, param_grid=parameters, cv=5, scoring="roc_auc")
gri_sear.fit(X, y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                       colsample_bytree=1.0,
#                                       importance_type='split',
#                                       learning_rate=0.1, max_depth=-1,
#                                       min_child_samples=20,
#                                       min_child_weight=0.001,
#                                       min_split_gain=0.0, n_estimators=100,
#                                       n_jobs=-1, num_leaves=31, objective=None,
#                                       random_state=None, reg_alpha=0.0,
#                                       reg_lambda=0.0, silent=True,
#                                       subsample=1.0, subsample_for_bin=200000,
#                                       subsample_freq=0),
#              iid='warn', n_jobs=None,
#              param_grid={'max_depth': [3, 5, 7, 10],
# ...

# %%
gri_sear.best_score_
# Out:
# 0.7385939981750549

# %% [markdown]
# ## Problem 5

# %% [markdown]
# Let's now choose a model and submit to Kaggle again and see our new score

# %%
df2 = pd.read_csv("application_test.csv")

# %%
X = df_mix[list_i].drop("TARGET", axis=1)
y = df_mix["TARGET"]
X = X[list_col]
df2 = pd.get_dummies(df2)

# %%
df2.isnull().sum()
# Out:
# SK_ID_CURR                          0
# CNT_CHILDREN                        0
# AMT_INCOME_TOTAL                    0
# AMT_CREDIT                          0
# AMT_ANNUITY                        24
#                                    ..
# WALLSMATERIAL_MODE_Panel            0
# WALLSMATERIAL_MODE_Stone, brick     0
# WALLSMATERIAL_MODE_Wooden           0
# EMERGENCYSTATE_MODE_No              0
# EMERGENCYSTATE_MODE_Yes             0
# Length: 242, dtype: int64

# %%
df2["NA_count"] = pd.DataFrame(df2.isnull().sum(axis=1))
df2 = df2[list_col]
for i in df2.columns:
    df2[i] = df2[i].replace(np.nan, 0)

# %%
clf = lgb.LGBMClassifier(max_depth=3, n_estimators=500).fit(X, y)
y_pred =clf.predict(df2)
y_pred_proba =clf.predict_proba(df2)

# %%
submission3 = pd.read_csv('./sample_submission.csv')
submission3["TARGET"] = y_pred_proba[:,1]
submission3.to_csv('./submission3.csv', index=False)

# %% [markdown]
# The new score in Kaggle is 0.72836 (Better than the previous submissions)

# %% [markdown]
# <img src="3.png">
